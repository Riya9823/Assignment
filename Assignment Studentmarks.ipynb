# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
import pandas as pd
con=mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="riya2398",
    database="Studentmarks")

df=pd.read_sql_query("select * from Studentmarks",con)
df
# Out:
#        Name Gender         Dob  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  1988-04-05     55       45         56       87        2
# 1    Suresh      M  1987-05-04     75       96         78       64       90
# 2    Ramesh      M  1990-05-25     25       54         89       76       95
# 3   Jessica      F  1989-08-12     78       96         86       63       54
# 4  Jennifer      F  1989-09-02     58       96         78       46       96
# 5      Annu      F  1988-04-05     45       87         52       89       55
# 6     Pooja      F  1987-05-04     55       64         61       58       75
# 7    Ritesh      M  1989-05-25     54       76         87       56       25
# 8     Farha      F  1990-08-12     55       63         89       75       78
# 9    Mukesh      M  1989-09-02     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# DataSet Describe

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  62.800000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  30.814138  14.629119
# min    25.000000  45.000000  52.000000  46.000000   2.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %% [markdown]
# Check Shape Of Dataset

# %%
df.shape
# Out:
# (10, 11)

# %% [markdown]
# Check DataSet Columns

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Dob', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics'],
#       dtype='object')

# %% [markdown]
# Check Missing Data

# %%
df.isnull().sum()
# Out:
# Name         0
# Gender       0
# Dob          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %% [markdown]
# Check Unique Values

# %%
df.nunique()
# Out:
# Name         10
# Gender        2
# Dob           7
# Maths         8
# Physics       8
# Chemistry     8
# English      10
# Biology      10
# Economics     9
# History      10
# Civics       10
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# Value Count of Dataset

# %%
df['Maths'].value_counts()
# Out:
# 55    3
# 78    1
# 45    1
# 75    1
# 58    1
# 25    1
# 54    1
# 96    1
# Name: Maths, dtype: int64

# %% [markdown]
# Percentage

# %%
print('Percentage',df.Maths.value_counts(normalize=True))
df.Maths.value_counts(normalize=True).plot(kind='bar')
# Out:
# Percentage 55    0.3
# 78    0.1
# 45    0.1
# 75    0.1
# 58    0.1
# 25    0.1
# 54    0.1
# 96    0.1
# Name: Maths, dtype: float64

# %% [markdown]
# Info about Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       10 non-null     object
#  1   Gender     10 non-null     object
#  2   Dob        10 non-null     object
#  3   Maths      10 non-null     int64
#  4   Physics    10 non-null     int64
#  5   Chemistry  10 non-null     int64
#  6   English    10 non-null     int64
#  7   Biology    10 non-null     int64
#  8   Economics  10 non-null     int64
#  9   History    10 non-null     int64
#  10  Civics     10 non-null     int64
# dtypes: int64(8), object(3)
# memory usage: 1008.0+ bytes

# %% [markdown]
# Relationship Analysis

# %%
cor=df.corr()

# %% [markdown]
# Heatmap

# %%
sns.heatmap(df.corr(),annot=True,)

# %%
sns.heatmap(df.isnull(),annot=True)
plt.show()

# %% [markdown]
# Boxplot

# %%
for i in df.describe().columns:
    sns.boxplot(df[i].dropna())
    plt.show()

# %%
sns.countplot( df['Gender'] )

# %% [markdown]
# Countplot

# %%
sns.countplot( df['Maths'] )

# %%
sns.countplot( df['English'] )

# %%
plt.figure(figsize=(10,5))
sns.countplot(df.Physics)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

# %% [markdown]
# Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# Relational Plot

# %%
sns.relplot(x='Maths', y='Economics', hue='Gender', data=df)

# %% [markdown]
# Distplot

# %%
sns.distplot(df['Chemistry'])

# %% [markdown]
# Lineplot

# %%
sns.lineplot(x="Maths",y="Physics",data=df)
plt.show()

# %%
sns.lineplot(x="Maths",y="Economics",data=df)
plt.show()

# %%
df.pivot_table('Civics', index='Maths', columns='Gender').plot()

# %% [markdown]
# Scatterplot

# %%
plt.figure(figsize=(10,5))
plt.xlabel("Maths")
plt.ylabel("English")
plt.title("Analysis of Marks Scored")
sns.scatterplot(x='Maths',y='English',data=df)

# %% [markdown]
# Violinplot

# %%
sns.violinplot(x="Biology", data=df)
plt.show()

# %%
sns.violinplot(x="History", data=df)
plt.show()

# %% [markdown]
# Pointplot

# %%
fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(10,5))
sns.pointplot(x='Physics', y='Chemistry', hue='Gender', data=df, ax=axis1)
sns.pointplot(x='Physics', y='Biology', hue='Gender', data=df, ax=axis2)
